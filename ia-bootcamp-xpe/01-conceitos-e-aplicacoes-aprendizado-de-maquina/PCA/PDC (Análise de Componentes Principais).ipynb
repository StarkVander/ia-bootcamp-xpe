# %% [markdown]
# # Análise de Componentes Principais (PCA)
#
# ## Introdução
#
# Em muitos problemas do mundo real, os conjuntos de dados costumam conter várias variáveis ou características. No entanto, nem todas essas variáveis são igualmente relevantes para a análise. Além disso, é difícil visualizar e interpretar dados que possuem mais de três dimensões.
#
# O PCA permite reduzir a dimensionalidade dos dados, mantendo a maior parte da informação relevante contida nas variáveis originais. Ele faz isso transformando as variáveis originais em um novo conjunto de variáveis, **chamadas de componentes principais**. Esses componentes são combinações lineares das variáveis originais e são ordenados de acordo com a quantidade de variação explicada que eles capturam.
#
# ![Ilustração PCA](./img/pca.jpg)
#
# A ideia principal do PCA é que as informações mais importantes contidas nos dados são aquelas relacionadas às direções de maior variação. **Os primeiros componentes principais capturam a maior parte da variância nos dados, enquanto os componentes subsequentes capturam cada vez menos variancia**. Dessa forma, podemos escolher reter apenas os primeiros componentes principais mais significativos e descartar os menos relevantes, reduzindo assim a dimensionalidade dos dados.
# ***

# %% [markdown]
# ### Importando as bibliotecas
# ***

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Carregar o conjunto de dados iris
iris = load_iris()
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 150 (50 in each of three classes)
# :Number of Attributes: 4 numeric, predictive attributes and the class
# :Attribute Information:
#     - sepal length in cm
#     - sepal width in cm
#     - petal length in cm
#     - petal width in cm
#     - class:
#             - Iris-Setosa
#             - Iris-Versicolour
#             - Iris-Virginica
#
# :Summary Statistics:
#
# ============== ==== ==== ======= ===== ====================
#                 Min  Max   Mean    SD   Class Correlation
# ============== ==== ==== ======= ===== ====================
# sepal length:   4.3  7.9   5.84   0.83    0.7826
# sepal width:    2.0  4.4   3.05   0.43   -0.4194
# petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
# petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ============== ==== ==== ======= ===== ====================
#
# ...

# %% [markdown]
# ### Estruturando base de dados
# ***

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['class'] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# ### Mapeamento variável target
# ***

# %%
class_map = {
    0 : 'Iris-Setosa',
    1 : 'Iris-Versicolour',
    2 : 'Iris-Virginica',
}

df['class'] = df['class'].map(class_map)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#          class
# 0  Iris-Setosa
# 1  Iris-Setosa
# 2  Iris-Setosa
# 3  Iris-Setosa
# 4  Iris-Setosa

# %% [markdown]
# ### Padronizando dados (StandardScaler)
# ***

# %%
# Separando valores da base
X = df.drop(columns='class').values
y = df['class']

# Criando instancia
scaler = StandardScaler()

# Padronizando os dados
X_padronizado = scaler.fit_transform(X)

# %% [markdown]
# ### Aplicando o PCA
# ***

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_padronizado)

# %% [markdown]
# ### Analisando a variancia explicada
# ***

# %%
variancia_explicada = pca.explained_variance_ratio_
print('Variancia explicada por cada componente principal: ', variancia_explicada)
# Out:
# Variancia explicada por cada componente principal:  [0.72962445 0.22850762]

# %% [markdown]
# ### Analisando componentes em relação as variaveis originais
# ***

# %%
df_components = pd.DataFrame(pca.components_, columns=df.columns[0:4], index=['PC1','PC2'])
df_components
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# PC1           0.521066         -0.269347           0.580413          0.564857
# PC2           0.377418          0.923296           0.024492          0.066942

# %% [markdown]
# ### Adicionando componentes principais
# ***

# %%
df['Componente principal 1'] = X_pca[:,0]
df['Componente principal 2'] = X_pca[:,1]
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#          class  Componente principal 1  Componente principal 2
# 0  Iris-Setosa               -2.264703                0.480027
# 1  Iris-Setosa               -2.080961               -0.674134
# 2  Iris-Setosa               -2.364229               -0.341908
# 3  Iris-Setosa               -2.299384               -0.597395
# 4  Iris-Setosa               -2.389842                0.646835

# %% [markdown]
# ### Visualizando Componentes principais
# ***

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(
    data=df,
    x='Componente principal 1',
    y='Componente principal 2',
    hue='class'
)
# Out:
# <Axes: xlabel='Componente principal 1', ylabel='Componente principal 2'>
